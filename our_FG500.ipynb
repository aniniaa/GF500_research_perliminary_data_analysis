# %% [markdown]
# ### Finding our FG500 customers

# %% [markdown]
# ### tracking changes in SBTi NT , NZ, CN targets and target dates

# %% [markdown]
# ### extracting company info into a sheet with a dashboard visual on excel
